# %%
# from sklearn.datasets import load_iris, load_digits, load_wine, load_breast_cancer, fetch_20newsgroups

# # Load datasets
# iris = load_iris()
# digits = load_digits()
# wine = load_wine()
# cancer = load_breast_cancer()
# newsgroups = fetch_20newsgroups(subset='train')

# # Access features and target
# X_iris, y_iris = iris.data, iris.target
# X_digits, y_digits = digits.data, digits.target
# X_wine, y_wine = wine.data, wine.target
# X_cancer, y_cancer = cancer.data, cancer.target
# X_newsgroups, y_newsgroups = newsgroups.data, newsgroups.target

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_wine
wine = load_wine()
x, y = wine.data, wine.target

# %% [markdown]
# ### with wine dataset

# %%
wine_df = pd.DataFrame(data=wine.data, columns=wine.feature_names)
wine_df['target'] = wine.target

plt.figure(figsize=(10, 6))
plt.scatter(wine_df['alcohol'], wine_df['malic_acid'], c=wine_df['target'], cmap='viridis', edgecolor='k')
plt.title('Scatter Plot of Alcohol vs Malic Acid')
plt.xlabel('Alcohol')
plt.ylabel('Malic Acid')
plt.colorbar(label='Wine Class')
plt.show()

# %% [markdown]
# ### with brest_cancer dataset

# %%
# Load the Breast Cancer dataset
cancer = load_breast_cancer()

# Convert to DataFrame
cancer_df = pd.DataFrame(data=cancer.data, columns=cancer.feature_names)
cancer_df['target'] = cancer.target

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(cancer_df['mean radius'], cancer_df['mean texture'], c=cancer_df['target'], cmap='viridis', edgecolor='k')
plt.title('Scatter Plot of Mean Radius vs Mean Texture')
plt.xlabel('Mean Radius')
plt.ylabel('Mean Texture')
plt.colorbar(label='Cancer Type')
plt.show()

# %% [markdown]
# ### model implementation

# %%
def perceptron():
# Out:
#   Cell In[7], line 1
#     def perceptron()
#                     ^
# SyntaxError: expected ':'
